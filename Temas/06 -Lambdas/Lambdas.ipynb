# %% [markdown]
# ### FUNCIÓN NORMAL

# %%
def incremento(x):
    return x + 1

# %%
resultado = incremento(10)
print(resultado)
# Out:
# 11

# %% [markdown]
# ### LAMBDA

# %% [markdown]
# ¿Qué es lambda?
#
# Son conocidas como Funciones Anónimas o lambdas, en donde no tienen un identificador o no tienen un nombre, se puede definir su estructura de la siguiente manera: lambda argumentos: expresión, las funciones lambda pueden tener los argumentos que se requieran pero solo una linea de código o una expresión.

# %% [markdown]
# Estructura de Lambda
#
# lambda arguments: valor_retorno

# %%
lambda x: x + 1
# Out:
# <function __main__.<lambda>(x)>

# %%
increment = lambda x: x + 1
print(increment(10))
# Out:
# 11

# %%
fullname = lambda name, lastname: f'Tu nombre completo es {name.title()} {lastname.title()}'
print(fullname('eduardo','dominguez'))
# Out:
# Tu nombre completo es Eduardo Dominguez

# %%
operacion = lambda num: num + 10
print(operacion())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-1f2a8e41526d> in <cell line: 1>()
# ----> 1 operacion = suma(lambda num: num + 10)
#       2 print(suma(2))
#
# NameError: name 'suma' is not defined
